# %% [markdown]
# # Table of contents
#
# * [Certification](#certification)
# * [Display figure](#disp_fig)
#     * [Import libraries](#libs)
#     * [Perform computations](#perf_comps)

# %% [markdown]
# # <a id="certification"></a><span style='color:rgb(51,122,183)'>Certification</span>
#
# Your output file must contain the following certification:
#
# > I certify that this project is my own work and is not the work of others. I agree not to share my solution with others. - Michael Navarro

# %% [markdown]
# # <a id="disp_fig"></a><span style='color:rgb(51,122,183)'>Display figure</span>

# %% [markdown]
# # <a id="libs"></a><span style='color:rgb(51,122,183)'>Import libraries</span>

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # <a id="perf_comps"></a><span style='color:rgb(51,122,183)'>Perform computations</span>
#
# Compute values for and plot the following function:
# $$f(t) = \exp(t)*\sin(2\pi t)$$

# %%
t = np.arange(0, 6.0, 0.05)
plt.plot(t, np.exp(t) * np.sin(2*np.pi*t))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# `##The End##`
